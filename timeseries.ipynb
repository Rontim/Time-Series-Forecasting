# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset_train = pd.read_csv('Google_Stock_Price_Train.csv')

training_set = dataset_train['Open'].values.reshape(-1, 1)
training_set.shape
dataset_train
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = scaler.fit_transform(training_set)

# %%
X_train = [training_set_scaled[i-60:i, 0] for i in range(60, 1258)]
y_train = [training_set_scaled[i, 0] for i in range(60, 1258)]
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train
# Out:
# array([[[0.08581368],
#         [0.09701243],
#         [0.09433366],
#         ...,
#         [0.07846566],
#         [0.08034452],
#         [0.08497656]],
#
#        [[0.09701243],
#         [0.09433366],
#         [0.09156187],
#         ...,
#         [0.08034452],
#         [0.08497656],
#         [0.08627874]],
#
#        [[0.09433366],
#         [0.09156187],
#         [0.07984225],
#         ...,
#         [0.08497656],
#         [0.08627874],
#         [0.08471612]],
#
#        ...,
#
#        [[0.92106928],
#         [0.92438053],
#         [0.93048218],
#         ...,
#         [0.95475854],
#         [0.95204256],
#         [0.95163331]],
#
#        [[0.92438053],
#         [0.93048218],
#         [0.9299055 ],
#         ...,
#         [0.95204256],
#         [0.95163331],
#         [0.95725128]],
#
#        [[0.93048218],
#         [0.9299055 ],
#         [0.93113327],
#         ...,
#         [0.95163331],
#         [0.95725128],
#         [0.93796041]]])

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
regressor = Sequential([
    LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)),
    Dropout(0.2),
    LSTM(units=50, return_sequences=True),
    Dropout(0.2),
    LSTM(units=50, return_sequences=True),
    Dropout(0.2),
    LSTM(units=50),
    Dropout(0.2),
    Dense(units=1)
])

regressor.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# 2023-06-26 00:23:29.967405: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-06-26 00:23:34.955579: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:23:34.959315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:23:34.961320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:23:35.494187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:23:35.499727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:23:35.504756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:23:36.227324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:23:36.231806: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:23:36.236331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:23:36.922134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:23:36.925282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:23:36.927510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
regressor.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 2023-06-26 00:24:32.528307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:24:32.531295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:24:32.533573: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:24:33.022642: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:24:33.027704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:24:33.030972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:24:33.778947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:24:33.784287: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:24:33.790393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:24:34.407996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:24:34.410889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:24:34.413059: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:24:38.831025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:24:38.834084: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:24:38.837152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:24:39.524340: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:24:39.529888: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:24:39.533365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:24:40.271221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:24:40.301282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:24:40.305152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 00:24:40.821421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 00:24:40.825884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 00:24:40.831857: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 38/38 [==============================] - 41s 555ms/step - loss: 0.0462
# Epoch 2/100
# 38/38 [==============================] - 23s 609ms/step - loss: 0.0073
# Epoch 3/100
# 38/38 [==============================] - 25s 656ms/step - loss: 0.0055
# Epoch 4/100
# 38/38 [==============================] - 24s 627ms/step - loss: 0.0054
# Epoch 5/100
# 38/38 [==============================] - 24s 614ms/step - loss: 0.0043
# Epoch 6/100
# 38/38 [==============================] - 25s 655ms/step - loss: 0.0054
# Epoch 7/100
# 38/38 [==============================] - 25s 648ms/step - loss: 0.0051
# Epoch 8/100
# 38/38 [==============================] - 29s 771ms/step - loss: 0.0047
# Epoch 9/100
# 38/38 [==============================] - 21s 557ms/step - loss: 0.0047
# Epoch 10/100
# 38/38 [==============================] - 22s 582ms/step - loss: 0.0041
# Epoch 11/100
# 38/38 [==============================] - 25s 646ms/step - loss: 0.0041
# Epoch 12/100
# 38/38 [==============================] - 25s 640ms/step - loss: 0.0037
# Epoch 13/100
# 38/38 [==============================] - 27s 717ms/step - loss: 0.0042
# Epoch 14/100
# 38/38 [==============================] - 24s 637ms/step - loss: 0.0048
# Epoch 15/100
# 38/38 [==============================] - 24s 629ms/step - loss: 0.0038
# Epoch 16/100
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0037
# Epoch 17/100
# 38/38 [==============================] - 27s 697ms/step - loss: 0.0040
# Epoch 18/100
# 38/38 [==============================] - 25s 647ms/step - loss: 0.0038
# Epoch 19/100
# 38/38 [==============================] - 23s 616ms/step - loss: 0.0036
# Epoch 20/100
# 38/38 [==============================] - 25s 653ms/step - loss: 0.0035
# Epoch 21/100
# 38/38 [==============================] - 25s 648ms/step - loss: 0.0034
# Epoch 22/100
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0032
# Epoch 23/100
# 38/38 [==============================] - 24s 637ms/step - loss: 0.0032
# Epoch 24/100
# 38/38 [==============================] - 25s 662ms/step - loss: 0.0034
# Epoch 25/100
# 38/38 [==============================] - 24s 629ms/step - loss: 0.0038
# Epoch 26/100
# 38/38 [==============================] - 25s 664ms/step - loss: 0.0041
# Epoch 27/100
# 38/38 [==============================] - 22s 584ms/step - loss: 0.0031
# Epoch 28/100
# 38/38 [==============================] - 24s 623ms/step - loss: 0.0031
# Epoch 29/100
# 38/38 [==============================] - 25s 662ms/step - loss: 0.0028
# Epoch 30/100
# 38/38 [==============================] - 24s 623ms/step - loss: 0.0030
# Epoch 31/100
# 38/38 [==============================] - 23s 601ms/step - loss: 0.0029
# Epoch 32/100
# 38/38 [==============================] - 22s 570ms/step - loss: 0.0027
# Epoch 33/100
# 38/38 [==============================] - 25s 639ms/step - loss: 0.0036
# Epoch 34/100
# 38/38 [==============================] - 24s 620ms/step - loss: 0.0032
# Epoch 35/100
# 38/38 [==============================] - 22s 576ms/step - loss: 0.0026
# Epoch 36/100
# 38/38 [==============================] - 26s 691ms/step - loss: 0.0029
# Epoch 37/100
# 38/38 [==============================] - 25s 657ms/step - loss: 0.0027
# Epoch 38/100
# 38/38 [==============================] - 25s 653ms/step - loss: 0.0028
# Epoch 39/100
# 38/38 [==============================] - 23s 622ms/step - loss: 0.0029
# Epoch 40/100
# 38/38 [==============================] - 25s 655ms/step - loss: 0.0027
# Epoch 41/100
# 38/38 [==============================] - 24s 612ms/step - loss: 0.0025
# Epoch 42/100
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0027
# Epoch 43/100
# 38/38 [==============================] - 25s 648ms/step - loss: 0.0025
# Epoch 44/100
# 38/38 [==============================] - 24s 614ms/step - loss: 0.0024
# Epoch 45/100
# 38/38 [==============================] - 23s 604ms/step - loss: 0.0023
# Epoch 46/100
# 38/38 [==============================] - 24s 623ms/step - loss: 0.0026
# Epoch 47/100
# 38/38 [==============================] - 24s 638ms/step - loss: 0.0021
# Epoch 48/100
# 38/38 [==============================] - 28s 729ms/step - loss: 0.0022
# Epoch 49/100
# 38/38 [==============================] - 26s 666ms/step - loss: 0.0023
# Epoch 50/100
# 38/38 [==============================] - 20s 533ms/step - loss: 0.0027
# Epoch 51/100
# 38/38 [==============================] - 23s 615ms/step - loss: 0.0024
# Epoch 52/100
# 38/38 [==============================] - 20s 533ms/step - loss: 0.0020
# Epoch 53/100
# 38/38 [==============================] - 29s 773ms/step - loss: 0.0026
# Epoch 54/100
# 38/38 [==============================] - 29s 769ms/step - loss: 0.0024
# Epoch 55/100
# 38/38 [==============================] - 26s 661ms/step - loss: 0.0024
# Epoch 56/100
# 38/38 [==============================] - 26s 675ms/step - loss: 0.0022
# Epoch 57/100
# 38/38 [==============================] - 24s 640ms/step - loss: 0.0019
# Epoch 58/100
# 38/38 [==============================] - 23s 612ms/step - loss: 0.0024
# Epoch 59/100
# 38/38 [==============================] - 30s 784ms/step - loss: 0.0022
# Epoch 60/100
# 38/38 [==============================] - 28s 733ms/step - loss: 0.0021
# Epoch 61/100
# 38/38 [==============================] - 26s 685ms/step - loss: 0.0021
# Epoch 62/100
# 38/38 [==============================] - 29s 751ms/step - loss: 0.0023
# Epoch 63/100
# 38/38 [==============================] - 26s 670ms/step - loss: 0.0019
# Epoch 64/100
# 38/38 [==============================] - 23s 606ms/step - loss: 0.0020
# Epoch 65/100
# 38/38 [==============================] - 16s 433ms/step - loss: 0.0019
# Epoch 66/100
# 38/38 [==============================] - 19s 510ms/step - loss: 0.0019
# Epoch 67/100
# 38/38 [==============================] - 17s 444ms/step - loss: 0.0021
# Epoch 68/100
# 38/38 [==============================] - 17s 438ms/step - loss: 0.0020
# Epoch 69/100
# 38/38 [==============================] - 20s 514ms/step - loss: 0.0020
# Epoch 70/100
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0021
# Epoch 71/100
# 38/38 [==============================] - 24s 635ms/step - loss: 0.0018
# Epoch 72/100
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0018
# Epoch 73/100
# 38/38 [==============================] - 21s 541ms/step - loss: 0.0019
# Epoch 74/100
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0017
# Epoch 75/100
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0017
# Epoch 76/100
# 38/38 [==============================] - 21s 559ms/step - loss: 0.0016
# Epoch 77/100
# 38/38 [==============================] - 15s 383ms/step - loss: 0.0018
# Epoch 78/100
# 38/38 [==============================] - 16s 424ms/step - loss: 0.0018
# Epoch 79/100
# 38/38 [==============================] - 17s 440ms/step - loss: 0.0017
# Epoch 80/100
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0018
# Epoch 81/100
# 38/38 [==============================] - 15s 400ms/step - loss: 0.0019
# Epoch 82/100
# 38/38 [==============================] - 16s 425ms/step - loss: 0.0016
# Epoch 83/100
# 38/38 [==============================] - 17s 443ms/step - loss: 0.0017
# Epoch 84/100
# 38/38 [==============================] - 14s 369ms/step - loss: 0.0016
# Epoch 85/100
# 38/38 [==============================] - 16s 416ms/step - loss: 0.0016
# Epoch 86/100
# 38/38 [==============================] - 17s 440ms/step - loss: 0.0016
# Epoch 87/100
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0015
# Epoch 88/100
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0016
# Epoch 89/100
# 38/38 [==============================] - 25s 670ms/step - loss: 0.0016
# Epoch 90/100
# 38/38 [==============================] - 18s 470ms/step - loss: 0.0015
# Epoch 91/100
# 38/38 [==============================] - 18s 465ms/step - loss: 0.0014
# Epoch 92/100
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0017
# Epoch 93/100
# 38/38 [==============================] - 16s 423ms/step - loss: 0.0017
# Epoch 94/100
# 38/38 [==============================] - 26s 685ms/step - loss: 0.0015
# Epoch 95/100
# 38/38 [==============================] - 28s 739ms/step - loss: 0.0015
# Epoch 96/100
# 38/38 [==============================] - 28s 730ms/step - loss: 0.0014
# Epoch 97/100
# 38/38 [==============================] - 26s 689ms/step - loss: 0.0014
# Epoch 98/100
# 38/38 [==============================] - 26s 694ms/step - loss: 0.0016
# Epoch 99/100
# 38/38 [==============================] - 25s 651ms/step - loss: 0.0015
# Epoch 100/100
# 38/38 [==============================] - 24s 619ms/step - loss: 0.0014

# %%
dataset_test = pd.read_csv('Google_Stock_Price_Test.csv')
# real_stock_price = dataset_test.iloc[:, 1:2].values
dataset_test
# Out:
#          Date    Open    High     Low   Close     Volume
# 0    1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1    1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2    1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3    1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4    1/9/2017  806.40  809.97  802.83  806.65  1,272,400
# 5   1/10/2017  807.86  809.13  803.51  804.79  1,176,800
# 6   1/11/2017  805.00  808.15  801.37  807.91  1,065,900
# 7   1/12/2017  807.14  807.39  799.17  806.36  1,353,100
# 8   1/13/2017  807.48  811.22  806.69  807.88  1,099,200
# 9   1/17/2017  807.08  807.14  800.37  804.61  1,362,100
# 10  1/18/2017  805.81  806.21  800.99  806.07  1,294,400
# 11  1/19/2017  805.12  809.48  801.80  802.17    919,300
# 12  1/20/2017  806.91  806.91  801.69  805.02  1,670,000
# 13  1/23/2017  807.25  820.87  803.74  819.31  1,963,600
# 14  1/24/2017  822.30  825.90  817.82  823.87  1,474,000
# 15  1/25/2017  829.62  835.77  825.06  835.67  1,494,500
# 16  1/26/2017  837.81  838.00  827.01  832.15  2,973,900
# 17  1/27/2017  834.71  841.95  820.44  823.31  2,965,800
# 18  1/30/2017  814.66  815.84  799.80  802.32  3,246,600
# 19  1/31/2017  796.86  801.25  790.52  796.79  2,160,600

# %%
real_stock_price = dataset_test['Open'].values.reshape(-1, 1)
real_stock_price
# Out:
# array([[778.81],
#        [788.36],
#        [786.08],
#        [795.26],
#        [806.4 ],
#        [807.86],
#        [805.  ],
#        [807.14],
#        [807.48],
#        [807.08],
#        [805.81],
#        [805.12],
#        [806.91],
#        [807.25],
#        [822.3 ],
#        [829.62],
#        [837.81],
#        [834.71],
#        [814.66],
#        [796.86]])

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)
X_test = []
for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 2023-06-26 01:10:00.951233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 01:10:00.988813: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 01:10:00.993364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 01:10:01.357124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 01:10:01.360985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 01:10:01.365395: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 01:10:01.807309: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 01:10:01.810513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 01:10:01.813675: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-06-26 01:10:02.670660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-06-26 01:10:02.675085: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-06-26 01:10:02.679671: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 8s 8s/step

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
